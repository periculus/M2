# %% [markdown]
# # M2 Jupyter Kernel Test
#
# Testing auto-completion and syntax highlighting

# %%
-- Test basic arithmetic
2 + 2

# %%
-- Test ring creation
R = QQ[x,y,z]

# %%
-- Test auto-completion: type 'ri' and press Tab
ri

# %%
-- Test matrix operations
M = matrix{{x,y},{y,z}}
det M

# %%
-- Test ideal operations
I = ideal(x^2, y^2, z^2)
gb I

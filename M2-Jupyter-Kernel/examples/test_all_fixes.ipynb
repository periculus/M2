# %% [markdown]
# # Test All Fixes
#
# This notebook tests all the recent fixes.

# %%
-- Test 1: Semicolon suppression
gbTrace = 2;

# %%
-- Test 2: Multiple commands with proper ordering
R = QQ[x,y,z]
I = ideal(x^2-y, y^2-z)
gb I
res I

# %%
-- Test 3: %latex toggle
%latex off

# %%
-- Should show plain text
matrix {{1,2},{3,4}}

# %%
%latex on

# %%
-- Should show LaTeX
matrix {{1,2},{3,4}}

# %%
-- Test 4: Progress with specific command
%pi 2 gb ideal(x^3, y^3, z^3)

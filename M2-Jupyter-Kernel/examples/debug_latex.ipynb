# %% [markdown]
# # Debug LaTeX Output
#
# Simple tests to debug why LaTeX is not showing

# %%
-- Test 1: Simple matrix that should show LaTeX
matrix {{1,2},{3,4}}

# %%
-- Test 2: Check if %help works (magic command)
%help

# %%
-- Test 3: Simple ideal
R = QQ[x,y]
ideal(x^2-y)

# %% [markdown]
# # Complete Intersections in Macaulay2
#
# This notebook demonstrates advanced Macaulay2 features including matrix factorizations and Ext computations, adapted from the "Computations in Algebraic Geometry with Macaulay2" book.

# %% [markdown]
# ## Matrix Factorizations
#
# First, let's explore matrix factorizations in the context of complete intersections.

# %%
-- Create a polynomial ring
A = QQ[w,x,y,z]

-- Define a 2x2 matrix
U = matrix {{w,x},{y,z}}

-- Create a chain complex from the matrix
C = chainComplex U

-- Compute homology
L = HH_0 C
# Out:
# 5:0A = QQ[w,x,y,z]
#
# o2 = $A$
#
# o2 : <span><samp class="token class-name">PolynomialRing</samp></span>
# 8:0U = matrix {{w,x},{y,z}}
#
# o3 = $\left(\!\begin{array}{cc}
# w&amp;x\\
# y&amp;z
# \end{array}\!\right)$
#
# o3 : <span><samp class="token class-name">Matrix</samp> $A^{2}\,\longleftarrow \,A^{2}$</span>
# 11:0C = chainComplex U
#
# o4 = $\underset{\vphantom{\Big|}0}{A^{2}}\,\xleftarrow{\left(\!\begin{array}{cc}
# w&amp;x\\
# y&amp;z
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}1}{A^{2}}$
#
# o4 : <samp class="token class-name">ChainComplex</samp>
# 14:0L = HH_0 C
#
# o5 = $\texttt{cokernel}\ \left(\!\begin{array}{cc}
# w&amp;x\\
# y&amp;z
# \end{array}\!\right)$
#
# o5 : <span>$A$-module, <samp class="token function">quotient</samp> of $A^{2}$</span>

# %%
det(U)
# Out:
# 17:0det(U)
#
# o6 = $-x\,y+w\,z$
#
# o6 : $A$

# %%
-- The determinant annihilates the homology
f = -det U
print("Determinant: ", f)

-- Verify that f annihilates L
f * L == 0
# Out:
# 20:0f = -det U
#
# o7 = $x\,y-w\,z$
#
# o7 : $A$
# 23:0print("Determinant: ", f)
# $\left(\texttt{Determinant: },\,x\,y-w\,z\right)$
# 26:0f * L == 0
#
# o9 = <samp class="token constant">true</samp>

# %%
-- Construct a null homotopy
s = nullhomotopy (-f * id_C)

-- Verify the homotopy property
s * C.dd + C.dd * s == -f
# Out:
# 29:0s = nullhomotopy (-f * id_C)
#
# o10 = $\left\{\begin{aligned}&amp;1:A^{2}\,\xleftarrow{\begin{array}{l}\left\{1\right\}\vphantom{z-x}\\\left\{1\right\}\vphantom{-yw}\end{array}\left(\!\begin{array}{cc}
# \vphantom{\left\{1\right\}}z&amp;-x\\
# \vphantom{\left\{1\right\}}-y&amp;w
# \end{array}\!\right)}\,A^{2}:0\end{aligned}\right\}$
#
# o10 : <samp class="token class-name">ChainComplexMap</samp>
# 32:0s * C.dd + C.dd * s == -f
#
# o11 = <samp class="token constant">true</samp>

# %% [markdown]
# ## Complete Intersection Example
#
# Now let's work with a specific complete intersection.

# %%
-- Define a new ring and a cubic polynomial
A = QQ[x,y,z]
f = x^3 + 3*y^3 - 2*y*z^2 + 5*z^3

-- Create the quotient ring
B = A/f

-- The maximal ideal
m = ideal(x,y,z)

-- Create a module
M = B^1/m^2
# Out:
# 35:0A = QQ[x,y,z]
#
# o12 = $A$
#
# o12 : <span><samp class="token class-name">PolynomialRing</samp></span>
# 38:0f = x^3 + 3*y^3 - 2*y*z^2 + 5*z^3
#
# o13 = $x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}$
#
# o13 : $A$
# 41:0B = A/f
#
# o14 = $B$
#
# o14 : <samp class="token class-name">QuotientRing</samp>
# 44:0m = ideal(x,y,z)
#
# o15 = $\texttt{ideal}{}\left(x,\,y,\,z\right)$
#
# o15 : <span><samp class="token class-name">Ideal</samp> of $B$</span>
# 47:0M = B^1/m^2
#
# o16 = $\texttt{cokernel}\ \left(\!\begin{array}{cccccc}
# x^{2}&amp;x\,y&amp;x\,z&amp;y^{2}&amp;y\,z&amp;z^{2}
# \end{array}\!\right)$
#
# o16 : <span>$B$-module, <samp class="token function">quotient</samp> of $B^{1}$</span>

# %%
F = resolution(M, LengthLimit=>8)
# Out:
# 50:0F = resolution(M, LengthLimit=>8)
#
# o17 = $\underset{\vphantom{\Big|}0}{B^{1}}\,\xleftarrow{\left(\!\begin{array}{cccccc}
# x^{2}&amp;x\ y&amp;x\ z&amp;y^{2}&amp;y\ z&amp;z^{2}
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}1}{B^{6}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# 0&amp;\cdots&amp;x\\
# 0&amp;\cdots&amp;0\\
# 0&amp;\cdots&amp;0\\
# 0&amp;\cdots&amp;3\,y\\
# -z&amp;\cdots&amp;-2\,z\\
# y&amp;\cdots&amp;5\,z
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}2}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x&amp;\cdots&amp;-2\,x^{2}\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x^{2}
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}3}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# -x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}4}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x&amp;\cdots&amp;-2\,x\ y+5\,x\ z\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x\ y
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}5}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;0
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}6}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x^{2}
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}7}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}8}{B^{9}}$
#
# o17 : <samp class="token class-name">ChainComplex</samp>

# %%
-- Compute a resolution
F = resolution(M, LengthLimit=>8)
# Out:
# 59:0F = resolution(M, LengthLimit=>8)
#
# o20 = $\underset{\vphantom{\Big|}0}{B^{1}}\,\xleftarrow{\left(\!\begin{array}{cccccc}
# x^{2}&amp;x\ y&amp;x\ z&amp;y^{2}&amp;y\ z&amp;z^{2}
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}1}{B^{6}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# 0&amp;\cdots&amp;x\\
# 0&amp;\cdots&amp;0\\
# 0&amp;\cdots&amp;0\\
# 0&amp;\cdots&amp;3\,y\\
# -z&amp;\cdots&amp;-2\,z\\
# y&amp;\cdots&amp;5\,z
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}2}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x&amp;\cdots&amp;-2\,x^{2}\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x^{2}
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}3}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# -x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}4}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x&amp;\cdots&amp;-2\,x\ y+5\,x\ z\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x\ y
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}5}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;0
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}6}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x^{2}
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}7}{B^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}8}{B^{9}}$
#
# o20 : <samp class="token class-name">ChainComplex</samp>

# %% [markdown]
# ## Matrix Factorization Function
#
# Let's define a function to compute matrix factorizations systematically.

# %%
restrict1 = N -> cokernel(lift(presentation N, A) | f)
# Out:
# 62:0restrict1 = N -> cokernel(lift(presentation N, A) | f)
#
# o21 = <samp class="token function">restrict1</samp>
#
# o21 : <samp class="token class-name">FunctionClosure</samp>

# %%
-- Helper function to restrict to the polynomial ring
restrict1 = N -> coker(lift(presentation N,A) | f)
# Out:
# 65:0restrict1 = N -> coker(lift(presentation N,A) | f)
#
# o22 = <samp class="token function">restrict1</samp>
#
# o22 : <samp class="token class-name">FunctionClosure</samp>

# %%
-- Extract a module from the resolution
L = restrict1 cokernel F.dd_4
# Out:
# 68:0L = restrict1 cokernel F.dd_4
#
# o23 = $\texttt{cokernel}\ \begin{array}{l}\left\{4\right\}\vphantom{-x^{2}3\,y^{2}02\,y\,z-5\,z^{2}2\,y\,z-5\,z^{2}02\,y^{2}-5\,y\,z00x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}00000000}\\\left\{4\right\}\vphantom{00-x^{2}03\,y^{2}3\,x\,y2\,y\,z-5\,z^{2}000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}0000000}\\\left\{4\right\}\vphantom{00-x\,y0-x^{2}3\,y^{2}02\,y\,z-5\,z^{2}000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}000000}\\\left\{5\right\}\vphantom{-y-x000000-2\,y+5\,z000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}00000}\\\left\{5\right\}\vphantom{z0-y-x-x00000000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}0000}\\\left\{5\right\}\vphantom{0z0y0-x00000000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}000}\\\left\{5\right\}\vphantom{00z000-x03\,y000000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}00}\\\left\{5\right\}\vphantom{0000z0y-x00000000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}0}\\\left\{5\right\}\vphantom{00000z0yx00000000x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}}\end{array}\left(\!\begin{array}{cccccccccccccccccc}
# \vphantom{\left\{4\right\}}-x^{2}&amp;3\,y^{2}&amp;0&amp;2\,y\,z-5\,z^{2}&amp;2\,y\,z-5\,z^{2}&amp;0&amp;2\,y^{2}-5\,y\,z&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;0&amp;-x^{2}&amp;0&amp;3\,y^{2}&amp;3\,x\,y&amp;2\,y\,z-5\,z^{2}&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;0&amp;-x\,y&amp;0&amp;-x^{2}&amp;3\,y^{2}&amp;0&amp;2\,y\,z-5\,z^{2}&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}-y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-2\,y+5\,z&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}z&amp;0&amp;-y&amp;-x&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;z&amp;0&amp;y&amp;0&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;z&amp;0&amp;0&amp;0&amp;-x&amp;0&amp;3\,y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;0&amp;z&amp;0&amp;y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;0&amp;0&amp;z&amp;0&amp;y&amp;x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;x^{3}+3\,y^{3}-2\,y\,z^{2}+5\,z^{3}
# \end{array}\!\right)$
#
# o23 : <span>$A$-module, <samp class="token function">quotient</samp> of $A^{9}$</span>

# %%
3/5 + 7/11
# Out:
# 71:03/5 + 7/11
#
# o24 = $\frac{68}{55}$
#
# o24 : ${\mathbb Q}$

# %%
-- Resolve it
C = res L

-- Get the first differential
U = C.dd_1
print("Matrix U:")
print U
# Out:
# 74:0C = res L
#
# o25 = $\underset{\vphantom{\Big|}0}{A^{9}}\,\xleftarrow{\left(\!\begin{array}{ccc}
# x^{2}&amp;\cdots&amp;0\\
# \vdots&amp;\ddots&amp;\vdots\\
# 0&amp;\cdots&amp;x
# \end{array}\!\right)}\,\underset{\vphantom{\Big|}1}{A^{9}}\,\xleftarrow{0}\,\underset{\vphantom{\Big|}2}{0}$
#
# o25 : <samp class="token class-name">ChainComplex</samp>
# 77:0U = C.dd_1
#
# o26 = $\begin{array}{l}\left\{4\right\}\vphantom{x^{2}0-2\,y\,z+5\,z^{2}0y^{2}-\frac{5}{2}y\,zy\,z-\frac{5}{2}z^{2}-\frac{5}{2}y\,z00}\\\left\{4\right\}\vphantom{0x^{2}-3\,y^{2}x\,yy\,z-\frac{5}{2}z^{2}0y\,z-\frac{5}{2}z^{2}00}\\\left\{4\right\}\vphantom{0x\,yx^{2}y^{2}000y\,z-\frac{5}{2}z^{2}0}\\\left\{5\right\}\vphantom{y00000\frac{1}{3}x0-2\,y+5\,z}\\\left\{5\right\}\vphantom{-zyx00-\frac{1}{2}x000}\\\left\{5\right\}\vphantom{000-\frac{1}{3}x0\frac{1}{2}y-\frac{1}{3}z00}\\\left\{5\right\}\vphantom{0-z00-\frac{1}{2}x0-\frac{1}{2}x03\,y}\\\left\{5\right\}\vphantom{00-z0\frac{1}{2}y0\frac{1}{2}y-\frac{1}{2}x0}\\\left\{5\right\}\vphantom{000\frac{1}{3}z000\frac{1}{2}yx}\end{array}\left(\!\begin{array}{ccccccccc}
# \vphantom{\left\{4\right\}}x^{2}&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;y^{2}-\frac{5}{2}y\,z&amp;y\,z-\frac{5}{2}z^{2}&amp;-\frac{5}{2}y\,z&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;x^{2}&amp;-3\,y^{2}&amp;x\,y&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;x\,y&amp;x^{2}&amp;y^{2}&amp;0&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0\\
# \vphantom{\left\{5\right\}}y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;\frac{1}{3}x&amp;0&amp;-2\,y+5\,z\\
# \vphantom{\left\{5\right\}}-z&amp;y&amp;x&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;-\frac{1}{3}x&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{3}z&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;-z&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;-\frac{1}{2}x&amp;0&amp;3\,y\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;-z&amp;0&amp;\frac{1}{2}y&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{2}x&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;\frac{1}{3}z&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;x
# \end{array}\!\right)$
#
# o26 : <span><samp class="token class-name">Matrix</samp> $A^{9}\,\longleftarrow \,A^{9}$</span>
# 80:0print("Matrix U:")
# <samp class="token string">Matrix U:</samp>
# 83:0print U
# $\begin{array}{l}\left\{4\right\}\vphantom{x^{2}0-2\,y\,z+5\,z^{2}0y^{2}-\frac{5}{2}y\,zy\,z-\frac{5}{2}z^{2}-\frac{5}{2}y\,z00}\\\left\{4\right\}\vphantom{0x^{2}-3\,y^{2}x\,yy\,z-\frac{5}{2}z^{2}0y\,z-\frac{5}{2}z^{2}00}\\\left\{4\right\}\vphantom{0x\,yx^{2}y^{2}000y\,z-\frac{5}{2}z^{2}0}\\\left\{5\right\}\vphantom{y00000\frac{1}{3}x0-2\,y+5\,z}\\\left\{5\right\}\vphantom{-zyx00-\frac{1}{2}x000}\\\left\{5\right\}\vphantom{000-\frac{1}{3}x0\frac{1}{2}y-\frac{1}{3}z00}\\\left\{5\right\}\vphantom{0-z00-\frac{1}{2}x0-\frac{1}{2}x03\,y}\\\left\{5\right\}\vphantom{00-z0\frac{1}{2}y0\frac{1}{2}y-\frac{1}{2}x0}\\\left\{5\right\}\vphantom{000\frac{1}{3}z000\frac{1}{2}yx}\end{array}\left(\!\begin{array}{ccccccccc}
# \vphantom{\left\{4\right\}}x^{2}&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;y^{2}-\frac{5}{2}y\,z&amp;y\,z-\frac{5}{2}z^{2}&amp;-\frac{5}{2}y\,z&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;x^{2}&amp;-3\,y^{2}&amp;x\,y&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;x\,y&amp;x^{2}&amp;y^{2}&amp;0&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0\\
# \vphantom{\left\{5\right\}}y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;\frac{1}{3}x&amp;0&amp;-2\,y+5\,z\\
# \vphantom{\left\{5\right\}}-z&amp;y&amp;x&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;-\frac{1}{3}x&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{3}z&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;-z&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;-\frac{1}{2}x&amp;0&amp;3\,y\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;-z&amp;0&amp;\frac{1}{2}y&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{2}x&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;\frac{1}{3}z&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;x
# \end{array}\!\right)$

# %%
oo
# Out:
# 86:0oo
#
# o29 = $\begin{array}{l}\left\{4\right\}\vphantom{x^{2}0-2\,y\,z+5\,z^{2}0y^{2}-\frac{5}{2}y\,zy\,z-\frac{5}{2}z^{2}-\frac{5}{2}y\,z00}\\\left\{4\right\}\vphantom{0x^{2}-3\,y^{2}x\,yy\,z-\frac{5}{2}z^{2}0y\,z-\frac{5}{2}z^{2}00}\\\left\{4\right\}\vphantom{0x\,yx^{2}y^{2}000y\,z-\frac{5}{2}z^{2}0}\\\left\{5\right\}\vphantom{y00000\frac{1}{3}x0-2\,y+5\,z}\\\left\{5\right\}\vphantom{-zyx00-\frac{1}{2}x000}\\\left\{5\right\}\vphantom{000-\frac{1}{3}x0\frac{1}{2}y-\frac{1}{3}z00}\\\left\{5\right\}\vphantom{0-z00-\frac{1}{2}x0-\frac{1}{2}x03\,y}\\\left\{5\right\}\vphantom{00-z0\frac{1}{2}y0\frac{1}{2}y-\frac{1}{2}x0}\\\left\{5\right\}\vphantom{000\frac{1}{3}z000\frac{1}{2}yx}\end{array}\left(\!\begin{array}{ccccccccc}
# \vphantom{\left\{4\right\}}x^{2}&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;y^{2}-\frac{5}{2}y\,z&amp;y\,z-\frac{5}{2}z^{2}&amp;-\frac{5}{2}y\,z&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;x^{2}&amp;-3\,y^{2}&amp;x\,y&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;0\\
# \vphantom{\left\{4\right\}}0&amp;x\,y&amp;x^{2}&amp;y^{2}&amp;0&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0\\
# \vphantom{\left\{5\right\}}y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;\frac{1}{3}x&amp;0&amp;-2\,y+5\,z\\
# \vphantom{\left\{5\right\}}-z&amp;y&amp;x&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;-\frac{1}{3}x&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{3}z&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;-z&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;-\frac{1}{2}x&amp;0&amp;3\,y\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;-z&amp;0&amp;\frac{1}{2}y&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{2}x&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;\frac{1}{3}z&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;x
# \end{array}\!\right)$
#
# o29 : <span><samp class="token class-name">Matrix</samp> $A^{9}\,\longleftarrow \,A^{9}$</span>

# %%
-- Find the complementary matrix V
s = nullhomotopy (-f * id_C)
V = s_0
print("Matrix V:")
print V

-- Verify the factorization
print("U*V + f == 0: ", U*V+f==0)
print("V*U + f == 0: ", V*U+f==0)
# Out:
# 89:0s = nullhomotopy (-f * id_C)
#
# o30 = $\left\{\begin{aligned}&amp;1:A^{9}\,\xleftarrow{\begin{array}{l}\left\{6\right\}\vphantom{-x00-3\,y^{2}-2\,y\,z+5\,z^{2}0-2\,y^{2}+5\,y\,z00}\\\left\{6\right\}\vphantom{0-x0-3\,y\,z-3\,y^{2}-3\,x\,y-2\,y\,z+5\,z^{2}00}\\\left\{6\right\}\vphantom{0y-x0000-2\,y\,z+5\,z^{2}0}\\\left\{6\right\}\vphantom{00-3\,y3\,x\,z3\,x\,y3\,x^{2}006\,y\,z-15\,z^{2}}\\\left\{6\right\}\vphantom{-3\,y2\,z03\,x^{2}06\,y\,z-15\,z^{2}2\,x^{2}-15\,y\,z-15\,x\,z}\\\left\{6\right\}\vphantom{2\,z0-2\,x02\,x^{2}-6\,y^{2}0-4\,y\,z+10\,z^{2}0}\\\left\{6\right\}\vphantom{3\,y00-3\,x^{2}0-6\,y\,z+15\,z^{2}0-6\,y^{2}+15\,y\,z-6\,x\,y+15\,x\,z}\\\left\{6\right\}\vphantom{002\,z0002\,x\,y2\,x^{2}-6\,y^{2}}\\\left\{6\right\}\vphantom{000-z^{2}-y\,z-x\,z-y^{2}-x\,y-x^{2}}\end{array}\left(\!\begin{array}{ccccccccc}
# \vphantom{\left\{6\right\}}-x&amp;0&amp;0&amp;-3\,y^{2}&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;-2\,y^{2}+5\,y\,z&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;-x&amp;0&amp;-3\,y\,z&amp;-3\,y^{2}&amp;-3\,x\,y&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;-3\,y&amp;3\,x\,z&amp;3\,x\,y&amp;3\,x^{2}&amp;0&amp;0&amp;6\,y\,z-15\,z^{2}\\
# \vphantom{\left\{6\right\}}-3\,y&amp;2\,z&amp;0&amp;3\,x^{2}&amp;0&amp;6\,y\,z-15\,z^{2}&amp;2\,x^{2}&amp;-15\,y\,z&amp;-15\,x\,z\\
# \vphantom{\left\{6\right\}}2\,z&amp;0&amp;-2\,x&amp;0&amp;2\,x^{2}&amp;-6\,y^{2}&amp;0&amp;-4\,y\,z+10\,z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}3\,y&amp;0&amp;0&amp;-3\,x^{2}&amp;0&amp;-6\,y\,z+15\,z^{2}&amp;0&amp;-6\,y^{2}+15\,y\,z&amp;-6\,x\,y+15\,x\,z\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;2\,z&amp;0&amp;0&amp;0&amp;2\,x\,y&amp;2\,x^{2}&amp;-6\,y^{2}\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;-z^{2}&amp;-y\,z&amp;-x\,z&amp;-y^{2}&amp;-x\,y&amp;-x^{2}
# \end{array}\!\right)}\,A^{9}:0\\&amp;2:0\,\xleftarrow{0}\,A^{9}:1\end{aligned}\right\}$
#
# o30 : <samp class="token class-name">ChainComplexMap</samp>
# 92:0V = s_0
#
# o31 = $\begin{array}{l}\left\{6\right\}\vphantom{-x00-3\,y^{2}-2\,y\,z+5\,z^{2}0-2\,y^{2}+5\,y\,z00}\\\left\{6\right\}\vphantom{0-x0-3\,y\,z-3\,y^{2}-3\,x\,y-2\,y\,z+5\,z^{2}00}\\\left\{6\right\}\vphantom{0y-x0000-2\,y\,z+5\,z^{2}0}\\\left\{6\right\}\vphantom{00-3\,y3\,x\,z3\,x\,y3\,x^{2}006\,y\,z-15\,z^{2}}\\\left\{6\right\}\vphantom{-3\,y2\,z03\,x^{2}06\,y\,z-15\,z^{2}2\,x^{2}-15\,y\,z-15\,x\,z}\\\left\{6\right\}\vphantom{2\,z0-2\,x02\,x^{2}-6\,y^{2}0-4\,y\,z+10\,z^{2}0}\\\left\{6\right\}\vphantom{3\,y00-3\,x^{2}0-6\,y\,z+15\,z^{2}0-6\,y^{2}+15\,y\,z-6\,x\,y+15\,x\,z}\\\left\{6\right\}\vphantom{002\,z0002\,x\,y2\,x^{2}-6\,y^{2}}\\\left\{6\right\}\vphantom{000-z^{2}-y\,z-x\,z-y^{2}-x\,y-x^{2}}\end{array}\left(\!\begin{array}{ccccccccc}
# \vphantom{\left\{6\right\}}-x&amp;0&amp;0&amp;-3\,y^{2}&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;-2\,y^{2}+5\,y\,z&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;-x&amp;0&amp;-3\,y\,z&amp;-3\,y^{2}&amp;-3\,x\,y&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;-3\,y&amp;3\,x\,z&amp;3\,x\,y&amp;3\,x^{2}&amp;0&amp;0&amp;6\,y\,z-15\,z^{2}\\
# \vphantom{\left\{6\right\}}-3\,y&amp;2\,z&amp;0&amp;3\,x^{2}&amp;0&amp;6\,y\,z-15\,z^{2}&amp;2\,x^{2}&amp;-15\,y\,z&amp;-15\,x\,z\\
# \vphantom{\left\{6\right\}}2\,z&amp;0&amp;-2\,x&amp;0&amp;2\,x^{2}&amp;-6\,y^{2}&amp;0&amp;-4\,y\,z+10\,z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}3\,y&amp;0&amp;0&amp;-3\,x^{2}&amp;0&amp;-6\,y\,z+15\,z^{2}&amp;0&amp;-6\,y^{2}+15\,y\,z&amp;-6\,x\,y+15\,x\,z\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;2\,z&amp;0&amp;0&amp;0&amp;2\,x\,y&amp;2\,x^{2}&amp;-6\,y^{2}\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;-z^{2}&amp;-y\,z&amp;-x\,z&amp;-y^{2}&amp;-x\,y&amp;-x^{2}
# \end{array}\!\right)$
#
# o31 : <span><samp class="token class-name">Matrix</samp> $A^{9}\,\longleftarrow \,A^{9}$</span>
# 95:0print("Matrix V:")
# <samp class="token string">Matrix V:</samp>
# 98:0print V
# $\begin{array}{l}\left\{6\right\}\vphantom{-x00-3\,y^{2}-2\,y\,z+5\,z^{2}0-2\,y^{2}+5\,y\,z00}\\\left\{6\right\}\vphantom{0-x0-3\,y\,z-3\,y^{2}-3\,x\,y-2\,y\,z+5\,z^{2}00}\\\left\{6\right\}\vphantom{0y-x0000-2\,y\,z+5\,z^{2}0}\\\left\{6\right\}\vphantom{00-3\,y3\,x\,z3\,x\,y3\,x^{2}006\,y\,z-15\,z^{2}}\\\left\{6\right\}\vphantom{-3\,y2\,z03\,x^{2}06\,y\,z-15\,z^{2}2\,x^{2}-15\,y\,z-15\,x\,z}\\\left\{6\right\}\vphantom{2\,z0-2\,x02\,x^{2}-6\,y^{2}0-4\,y\,z+10\,z^{2}0}\\\left\{6\right\}\vphantom{3\,y00-3\,x^{2}0-6\,y\,z+15\,z^{2}0-6\,y^{2}+15\,y\,z-6\,x\,y+15\,x\,z}\\\left\{6\right\}\vphantom{002\,z0002\,x\,y2\,x^{2}-6\,y^{2}}\\\left\{6\right\}\vphantom{000-z^{2}-y\,z-x\,z-y^{2}-x\,y-x^{2}}\end{array}\left(\!\begin{array}{ccccccccc}
# \vphantom{\left\{6\right\}}-x&amp;0&amp;0&amp;-3\,y^{2}&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;-2\,y^{2}+5\,y\,z&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;-x&amp;0&amp;-3\,y\,z&amp;-3\,y^{2}&amp;-3\,x\,y&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;-3\,y&amp;3\,x\,z&amp;3\,x\,y&amp;3\,x^{2}&amp;0&amp;0&amp;6\,y\,z-15\,z^{2}\\
# \vphantom{\left\{6\right\}}-3\,y&amp;2\,z&amp;0&amp;3\,x^{2}&amp;0&amp;6\,y\,z-15\,z^{2}&amp;2\,x^{2}&amp;-15\,y\,z&amp;-15\,x\,z\\
# \vphantom{\left\{6\right\}}2\,z&amp;0&amp;-2\,x&amp;0&amp;2\,x^{2}&amp;-6\,y^{2}&amp;0&amp;-4\,y\,z+10\,z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}3\,y&amp;0&amp;0&amp;-3\,x^{2}&amp;0&amp;-6\,y\,z+15\,z^{2}&amp;0&amp;-6\,y^{2}+15\,y\,z&amp;-6\,x\,y+15\,x\,z\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;2\,z&amp;0&amp;0&amp;0&amp;2\,x\,y&amp;2\,x^{2}&amp;-6\,y^{2}\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;-z^{2}&amp;-y\,z&amp;-x\,z&amp;-y^{2}&amp;-x\,y&amp;-x^{2}
# \end{array}\!\right)$
# 101:0print("U*V + f == 0: ", U*V+f==0)
# $\left(\texttt{U*V + f == 0: },\,\texttt{true}\right)$
# 104:0print("V*U + f == 0: ", V*U+f==0)
# $\left(\texttt{V*U + f == 0: },\,\texttt{true}\right)$

# %%
-- Define the matrix factorization function
matrixFactorization = M -> (
   B := ring M;
   f := (ideal B)_0;
   e := numgens B;
   F := resolution(M, LengthLimit => e+1);
   L := restrict1 cokernel F.dd_(e+1);
   C := res L;
   U := C.dd_1;
   s := nullhomotopy (-f * id_C);
   V := s_0;
   assert( U*V + f == 0 );
   assert( V*U + f == 0 );
   return (U,V));

# %%
matrixFactorization(B^1/m^3)
# Out:
# 131:0matrixFactorization(B^1/m^3)
#
# o40 = $\left(\begin{array}{l}\left\{5\right\}\vphantom{x^{2}0-2\,y\,z+5\,z^{2}0000y^{2}-\frac{5}{2}y\,z-\frac{5}{2}y^{2}+\frac{2}{3}y\,z-\frac{5}{3}z^{2}0y\,z-\frac{5}{2}z^{2}-\frac{5}{2}y\,z000}\\\left\{5\right\}\vphantom{0x^{2}-3\,y^{2}000x\,yy\,z-\frac{5}{2}z^{2}y^{2}-\frac{5}{2}y\,z00y\,z-\frac{5}{2}z^{2}000}\\\left\{5\right\}\vphantom{0x\,yx^{2}000y^{2}00y^{2}-\frac{5}{2}y\,z00y\,z-\frac{5}{2}z^{2}00}\\\left\{5\right\}\vphantom{000x^{2}y^{2}x\,y00-\frac{1}{3}y\,z+\frac{5}{6}z^{2}000000}\\\left\{5\right\}\vphantom{000-3\,x\,yx^{2}-3\,y^{2}000y\,z-\frac{5}{2}z^{2}00000}\\\left\{5\right\}\vphantom{000-3\,y^{2}x\,yx^{2}0000000y\,z-\frac{5}{2}z^{2}0}\\\left\{6\right\}\vphantom{000z0000-\frac{1}{6}x0000-\frac{1}{2}y0}\\\left\{6\right\}\vphantom{y0000000\frac{5}{6}x00\frac{1}{3}x00-2\,y+5\,z}\\\left\{6\right\}\vphantom{-zyx00000-\frac{1}{3}x0-\frac{1}{2}x0000}\\\left\{6\right\}\vphantom{000000-\frac{1}{3}x000\frac{1}{2}y-\frac{1}{3}z000}\\\left\{6\right\}\vphantom{0-z00000-\frac{1}{2}x000-\frac{1}{2}x003\,y}\\\left\{6\right\}\vphantom{00-z0y00\frac{1}{2}y000\frac{1}{2}y-\frac{1}{2}x00}\\\left\{6\right\}\vphantom{000x0y\frac{1}{3}z00000\frac{1}{2}y0x}\\\left\{6\right\}\vphantom{0000-z000\frac{1}{2}y-\frac{1}{2}x00000}\\\left\{6\right\}\vphantom{00000-z000\frac{1}{2}y000-\frac{1}{2}x0}\end{array}\left(\!\begin{array}{ccccccccccccccc}
# \vphantom{\left\{5\right\}}x^{2}&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;0&amp;0&amp;0&amp;y^{2}-\frac{5}{2}y\,z&amp;-\frac{5}{2}y^{2}+\frac{2}{3}y\,z-\frac{5}{3}z^{2}&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;-\frac{5}{2}y\,z&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;x^{2}&amp;-3\,y^{2}&amp;0&amp;0&amp;0&amp;x\,y&amp;y\,z-\frac{5}{2}z^{2}&amp;y^{2}-\frac{5}{2}y\,z&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;x\,y&amp;x^{2}&amp;0&amp;0&amp;0&amp;y^{2}&amp;0&amp;0&amp;y^{2}-\frac{5}{2}y\,z&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;x^{2}&amp;y^{2}&amp;x\,y&amp;0&amp;0&amp;-\frac{1}{3}y\,z+\frac{5}{6}z^{2}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;-3\,x\,y&amp;x^{2}&amp;-3\,y^{2}&amp;0&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{5\right\}}0&amp;0&amp;0&amp;-3\,y^{2}&amp;x\,y&amp;x^{2}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;y\,z-\frac{5}{2}z^{2}&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;z&amp;0&amp;0&amp;0&amp;0&amp;-\frac{1}{6}x&amp;0&amp;0&amp;0&amp;0&amp;-\frac{1}{2}y&amp;0\\
# \vphantom{\left\{6\right\}}y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;\frac{5}{6}x&amp;0&amp;0&amp;\frac{1}{3}x&amp;0&amp;0&amp;-2\,y+5\,z\\
# \vphantom{\left\{6\right\}}-z&amp;y&amp;x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-\frac{1}{3}x&amp;0&amp;-\frac{1}{2}x&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-\frac{1}{3}x&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{3}z&amp;0&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;-z&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0&amp;0&amp;3\,y\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;-z&amp;0&amp;y&amp;0&amp;0&amp;\frac{1}{2}y&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{2}x&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;x&amp;0&amp;y&amp;\frac{1}{3}z&amp;0&amp;0&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;0&amp;x\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;0&amp;-z&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;-\frac{1}{2}x&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{6\right\}}0&amp;0&amp;0&amp;0&amp;0&amp;-z&amp;0&amp;0&amp;0&amp;\frac{1}{2}y&amp;0&amp;0&amp;0&amp;-\frac{1}{2}x&amp;0
# \end{array}\!\right),\,\begin{array}{l}\left\{7\right\}\vphantom{-x000000-3\,y^{2}-2\,y\,z+5\,z^{2}0-2\,y^{2}+5\,y\,z0000}\\\left\{7\right\}\vphantom{0-x00000-3\,y\,z-3\,y^{2}-3\,x\,y-2\,y\,z+5\,z^{2}0000}\\\left\{7\right\}\vphantom{0y-x00000000-2\,y\,z+5\,z^{2}0-2\,y^{2}+5\,y\,z0}\\\left\{7\right\}\vphantom{000-x0y2\,y\,z-5\,z^{2}00000000}\\\left\{7\right\}\vphantom{000-3\,y-x00000000-2\,y\,z+5\,z^{2}0}\\\left\{7\right\}\vphantom{0000y-x00000000-2\,y\,z+5\,z^{2}}\\\left\{7\right\}\vphantom{00-3\,y000-6\,x\,y+15\,x\,z3\,x\,z3\,x\,y3\,x^{2}006\,y\,z-15\,z^{2}06\,y^{2}-15\,y\,z}\\\left\{7\right\}\vphantom{-3\,y2\,z000015\,x^{2}3\,x^{2}06\,y\,z-15\,z^{2}2\,x^{2}-15\,y\,z-15\,x\,z-15\,y^{2}-15\,x\,y}\\\left\{7\right\}\vphantom{000-6\,z006\,x^{2}000000-6\,y^{2}-6\,x\,y}\\\left\{7\right\}\vphantom{00002\,z06\,x\,y0000002\,x^{2}-6\,y^{2}}\\\left\{7\right\}\vphantom{2\,z0-2\,x4\,z00-4\,x^{2}02\,x^{2}-6\,y^{2}0-4\,y\,z+10\,z^{2}010\,y\,z4\,x\,y}\\\left\{7\right\}\vphantom{3\,y006\,y00-15\,x^{2}-3\,x^{2}0-6\,y\,z+15\,z^{2}0-6\,y^{2}+15\,y\,z-6\,x\,y+15\,x\,z15\,y^{2}15\,x\,y}\\\left\{7\right\}\vphantom{002\,z0-2\,y000002\,x\,y2\,x^{2}-6\,y^{2}00}\\\left\{7\right\}\vphantom{000002\,z6\,y^{2}0000002\,x\,y2\,x^{2}}\\\left\{7\right\}\vphantom{000x000-z^{2}-y\,z-x\,z-y^{2}-x\,y-x^{2}00}\end{array}\left(\!\begin{array}{ccccccccccccccc}
# \vphantom{\left\{7\right\}}-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-3\,y^{2}&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;-2\,y^{2}+5\,y\,z&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{7\right\}}0&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-3\,y\,z&amp;-3\,y^{2}&amp;-3\,x\,y&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{7\right\}}0&amp;y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0&amp;-2\,y^{2}+5\,y\,z&amp;0\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;-x&amp;0&amp;y&amp;2\,y\,z-5\,z^{2}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;-3\,y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-2\,y\,z+5\,z^{2}&amp;0\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;0&amp;y&amp;-x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-2\,y\,z+5\,z^{2}\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;-3\,y&amp;0&amp;0&amp;0&amp;-6\,x\,y+15\,x\,z&amp;3\,x\,z&amp;3\,x\,y&amp;3\,x^{2}&amp;0&amp;0&amp;6\,y\,z-15\,z^{2}&amp;0&amp;6\,y^{2}-15\,y\,z\\
# \vphantom{\left\{7\right\}}-3\,y&amp;2\,z&amp;0&amp;0&amp;0&amp;0&amp;15\,x^{2}&amp;3\,x^{2}&amp;0&amp;6\,y\,z-15\,z^{2}&amp;2\,x^{2}&amp;-15\,y\,z&amp;-15\,x\,z&amp;-15\,y^{2}&amp;-15\,x\,y\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;-6\,z&amp;0&amp;0&amp;6\,x^{2}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;-6\,y^{2}&amp;-6\,x\,y\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;0&amp;2\,z&amp;0&amp;6\,x\,y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;2\,x^{2}&amp;-6\,y^{2}\\
# \vphantom{\left\{7\right\}}2\,z&amp;0&amp;-2\,x&amp;4\,z&amp;0&amp;0&amp;-4\,x^{2}&amp;0&amp;2\,x^{2}&amp;-6\,y^{2}&amp;0&amp;-4\,y\,z+10\,z^{2}&amp;0&amp;10\,y\,z&amp;4\,x\,y\\
# \vphantom{\left\{7\right\}}3\,y&amp;0&amp;0&amp;6\,y&amp;0&amp;0&amp;-15\,x^{2}&amp;-3\,x^{2}&amp;0&amp;-6\,y\,z+15\,z^{2}&amp;0&amp;-6\,y^{2}+15\,y\,z&amp;-6\,x\,y+15\,x\,z&amp;15\,y^{2}&amp;15\,x\,y\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;2\,z&amp;0&amp;-2\,y&amp;0&amp;0&amp;0&amp;0&amp;0&amp;2\,x\,y&amp;2\,x^{2}&amp;-6\,y^{2}&amp;0&amp;0\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;0&amp;0&amp;2\,z&amp;6\,y^{2}&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;2\,x\,y&amp;2\,x^{2}\\
# \vphantom{\left\{7\right\}}0&amp;0&amp;0&amp;x&amp;0&amp;0&amp;0&amp;-z^{2}&amp;-y\,z&amp;-x\,z&amp;-y^{2}&amp;-x\,y&amp;-x^{2}&amp;0&amp;0
# \end{array}\!\right)\right)$
#
# o40 : <samp class="token class-name">Sequence</samp>

# %%
-- Test with a larger module
time (U,V) = matrixFactorization(B^1/m^3)
print("Size of U: ", (numrows U, numcols U))
print("Size of V: ", (numrows V, numcols V))
# Out:
# Error: -- used 0.009017s (cpu); 0.00901025s (thread); 0s (gc)\n
# -- used 0.009017s (cpu); 0.00901025s (thread); 0s (gc)

# %% [markdown]
# ## Ext Computations
#
# Now let's explore Ext groups and their structure.

# %%
-- Work over a finite field for efficiency
K = ZZ/103
A = K[x,Degrees=>{5}]
B = A/(x^3)

-- Define modules
M = B^1/(x^2)
N = B^1/(x)

-- Compute Ext
H = Ext(M,N)
print("Ext algebra:")
H
# Out:
# 143:0K = ZZ/103
#
# o44 = $K$
#
# o44 : <samp class="token class-name">QuotientRing</samp>
# 146:0A = K[x,Degrees=>{5}]
#
# o45 = $A$
#
# o45 : <span><samp class="token class-name">PolynomialRing</samp></span>
# 149:0B = A/(x^3)
#
# o46 = $B$
#
# o46 : <samp class="token class-name">QuotientRing</samp>
# 152:0M = B^1/(x^2)
#
# o47 = $\texttt{cokernel}\ \left(\!\begin{array}{c}
# x^{2}
# \end{array}\!\right)$
#
# o47 : <span>$B$-module, <samp class="token function">quotient</samp> of $B^{1}$</span>
# 155:0N = B^1/(x)
#
# o48 = $\texttt{cokernel}\ \left(\!\begin{array}{c}
# x
# \end{array}\!\right)$
#
# o48 : <span>$B$-module, <samp class="token function">quotient</samp> of $B^{1}$</span>
# 158:0H = Ext(M,N)
#
# o49 = $\texttt{cokernel}\ \begin{array}{l}\left\{0,\:0\right\}\vphantom{0x}\\\left\{-1,\:-10\right\}\vphantom{x0}\end{array}\left(\!\begin{array}{cc}
# \vphantom{\left\{0,\:0\right\}}0&amp;x\\
# \vphantom{\left\{-1,\:-10\right\}}x&amp;0
# \end{array}\!\right)$
#
# o49 : <span>$K\mathopen{}\left[X_{1},\,x\right]$-module, <samp class="token function">quotient</samp> of $\left(K\mathopen{}\left[X_{1},\,x\right]\right)^{2}$</span>
# 161:0print("Ext algebra:")
# <samp class="token string">Ext algebra:</samp>
# 164:0H
#
# o51 = $\texttt{cokernel}\ \begin{array}{l}\left\{0,\:0\right\}\vphantom{0x}\\\left\{-1,\:-10\right\}\vphantom{x0}\end{array}\left(\!\begin{array}{cc}
# \vphantom{\left\{0,\:0\right\}}0&amp;x\\
# \vphantom{\left\{-1,\:-10\right\}}x&amp;0
# \end{array}\!\right)$
#
# o51 : <span>$K\mathopen{}\left[X_{1},\,x\right]$-module, <samp class="token function">quotient</samp> of $\left(K\mathopen{}\left[X_{1},\,x\right]\right)^{2}$</span>

# %%
-- Examine the ring structure
ring H
degree \ gens ring H
# Out:
# 167:0ring H
#
# o52 = $K\mathopen{}\left[X_{1},\,x\right]$
#
# o52 : <span><samp class="token class-name">PolynomialRing</samp></span>
# 170:0degree \ gens ring H
#
# o53 = $\left\{\left\{-2,\:-15\right\},\:\left\{0,\:5\right\}\right\}$
#
# o53 : <samp class="token class-name">List</samp>

# %% [markdown]
# ## Even and Odd Parts of Ext
#
# Let's separate the even and odd degree components.

# %%
-- Define functions to extract even and odd parts
partSelector = predicate -> H -> (
   R := ring H;
   H' := prune image matrix {
       select(
           apply(numgens H, i -> H_{i}),
           f -> predicate first first degrees source f
           )
       };
   H');

evenPart = partSelector even
oddPart = partSelector odd
# Out:
# 173:0partSelector = predicate -> H -> (
# 174:0   R := ring H;
# 175:0   H' := prune image matrix {
# 176:0       select(
# 177:0           apply(numgens H, i -> H_{i}),
# 178:0           f -> predicate first first degrees source f
# 179:0           )
# 180:0       };
# 181:0   H');
# i55 : 182:0evenPart = partSelector even
#
# o55 = <samp class="token function">evenPart</samp>
#
# o55 : <samp class="token class-name">FunctionClosure</samp>
# i56 : 183:0oddPart = partSelector odd
#
# o56 = <samp class="token function">oddPart</samp>
#
# o56 : <samp class="token class-name">FunctionClosure</samp>

# %%
-- More interesting example
A = K[x,y]
J = ideal(x^3,y^2)
B = A/J
N = cokernel matrix{{x^2,x*y}}

-- Compute self-Ext
time H = Ext(N,N)
print("Full Ext:")
H
# Out:
# 186:0A = K[x,y]
#
# o57 = $A$
#
# o57 : <span><samp class="token class-name">PolynomialRing</samp></span>
# 189:0J = ideal(x^3,y^2)
#
# o58 = $\texttt{ideal}{}\left(x^{3},\,y^{2}\right)$
#
# o58 : <span><samp class="token class-name">Ideal</samp> of $A$</span>
# 192:0B = A/J
#
# o59 = $B$
#
# o59 : <samp class="token class-name">QuotientRing</samp>
# 195:0N = cokernel matrix{{x^2,x*y}}
#
# o60 = $\texttt{cokernel}\ \left(\!\begin{array}{cc}
# x^{2}&amp;x\,y
# \end{array}\!\right)$
#
# o60 : <span>$B$-module, <samp class="token function">quotient</samp> of $B^{1}$</span>
# Error: -- used 0.048082s (cpu); 0.014315s (thread); 0s (gc)\n
# -- used 0.048082s (cpu); 0.014315s (thread); 0s (gc)

# %%
-- Separate even and odd parts
print("Even part:")
evenPart H

print("\nOdd part:")
oddPart H
# Out:
# 207:0print("Even part:")
# <samp class="token string">Even part:</samp>
# 210:0evenPart H
#
# o65 = $\texttt{cokernel}\ \begin{array}{l}\left\{0,\:0\right\}\vphantom{y^{2}x\,yx^{2}X_{1}yX_{1}x00}\\\left\{-2,\:-2\right\}\vphantom{00000yx}\end{array}\left(\!\begin{array}{ccccccc}
# \vphantom{\left\{0,\:0\right\}}y^{2}&amp;x\,y&amp;x^{2}&amp;X_{1}y&amp;X_{1}x&amp;0&amp;0\\
# \vphantom{\left\{-2,\:-2\right\}}0&amp;0&amp;0&amp;0&amp;0&amp;y&amp;x
# \end{array}\!\right)$
#
# o65 : <span>$K\mathopen{}\left[X_{1}\,{.}{.}\,X_{2},\,x\,{.}{.}\,y\right]$-module, <samp class="token function">quotient</samp> of $\left(K\mathopen{}\left[X_{1}\,{.}{.}\,X_{2},\,x\,{.}{.}\,y\right]\right)^{2}$</span>
# 213:0print("\nOdd part:")
# <samp class="token string">
# Odd part:</samp>
# 216:0oddPart H
#
# o67 = $\texttt{cokernel}\ \begin{array}{l}\left\{-1,\:-1\right\}\vphantom{yx000000X_{1}0}\\\left\{-1,\:-1\right\}\vphantom{00yx00000X_{1}}\\\left\{-1,\:-1\right\}\vphantom{0000yx000X_{1}}\\\left\{-1,\:-1\right\}\vphantom{000000yx00}\end{array}\left(\!\begin{array}{cccccccccc}
# \vphantom{\left\{-1,\:-1\right\}}y&amp;x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;X_{1}&amp;0\\
# \vphantom{\left\{-1,\:-1\right\}}0&amp;0&amp;y&amp;x&amp;0&amp;0&amp;0&amp;0&amp;0&amp;X_{1}\\
# \vphantom{\left\{-1,\:-1\right\}}0&amp;0&amp;0&amp;0&amp;y&amp;x&amp;0&amp;0&amp;0&amp;X_{1}\\
# \vphantom{\left\{-1,\:-1\right\}}0&amp;0&amp;0&amp;0&amp;0&amp;0&amp;y&amp;x&amp;0&amp;0
# \end{array}\!\right)$
#
# o67 : <span>$K\mathopen{}\left[X_{1}\,{.}{.}\,X_{2},\,x\,{.}{.}\,y\right]$-module, <samp class="token function">quotient</samp> of $\left(K\mathopen{}\left[X_{1}\,{.}{.}\,X_{2},\,x\,{.}{.}\,y\right]\right)^{4}$</span>

# %% [markdown]
# ## Poincaré Series
#
# Finally, let's compute Poincaré series.

# %%
-- Set up ring for power series
T = ZZ[t,u,Inverses=>true,MonomialOrder=>RevLex]

-- Define Poincaré series functions
poincareSeries2 = M -> (
   B := ring M;
   k := B/ideal vars B;
   P := Ext(M,k);
   h := hilbertSeries P;
   T':= degreesRing P;
   substitute(h, {T'_0=>t^-1,T'_1=>u^-1})
   );

poincareSeries1 = M -> (
   substitute(poincareSeries2 M, {u=>1_T})
   );
# Out:
# 219:0T = ZZ[t,u,Inverses=>true,MonomialOrder=>RevLex]
#
# o68 = $T$
#
# o68 : <span><samp class="token class-name">PolynomialRing</samp></span>

# %%
-- Example computation
A' = K[x,y,z]
B' = A'/(x^2,y^2,z^3)
C' = res(B'^1/(x,y,z), LengthLimit => 6)
M' = coker transpose C'.dd_5

-- Compute Poincaré series
poincareSeries2 M'
# Out:
# Error: stdio:225:11:(3):[1]: error: expected modules over the same ring\n
# stdio:225:11:(3):[1]: error: expected modules over the same ring

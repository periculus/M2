# %% [markdown]
# # Test Progress Magic Commands
#
# This notebook tests the %pi and %%pi magic commands for progress indicators.

# %%
-- Setup
R = QQ[x,y,z]
I = ideal(x^2, y^2, z^2)

# %% [markdown]
# ## Test 1: Line magic %pi

# %%
%pi 1
gb I

# %% [markdown]
# ## Test 2: Cell magic %%pi

# %%
%%pi 2
gb I
res I

# %% [markdown]
# ## Test 3: No magic (baseline)

# %%
gb I

# %% [markdown]
# ## Test 4: Check gbTrace was not permanently modified

# %%
gbTrace

# %% [markdown]
# # LaTeX Output Test
#
# This notebook tests the LaTeX rendering capabilities.

# %%
-- Simple arithmetic (should show both text and LaTeX)
2 + 2
# Out:
# 6:0-- Simple arithmetic (should show both text and LaTeX)
# 7:02 + 2
#
# o3 = $4$

# %%
-- Matrix (should render as beautiful LaTeX matrix)
matrix{{1,2,3},{4,5,6}}
# Out:
# 10:0-- Matrix (should render as beautiful LaTeX matrix)
# 11:0matrix{{1,2,3},{4,5,6}}
#
# o4 = $\left(\!\begin{array}{ccc}
# 1&amp;2&amp;3\\
# 4&amp;5&amp;6
# \end{array}\!\right)$
#
# o4 : <span><samp class="token class-name">Matrix</samp> ${\mathbb Z}^{2}\,\longleftarrow \,{\mathbb Z}^{3}$</span>

# %%
-- Polynomial ring
R = QQ[x,y,z]
# Out:
# 14:0-- Polynomial ring
# 15:0R = QQ[x,y,z]
#
# o5 = $R$
#
# o5 : <span><samp class="token class-name">PolynomialRing</samp></span>

# %%
-- Ideal (should render with proper mathematical notation)
I = ideal(x^2 + y^2 - 1, x*y - z^2)
# Out:
# 18:0-- Ideal (should render with proper mathematical notation)
# 19:0I = ideal(x^2 + y^2 - 1, x*y - z^2)
#
# o6 = $\texttt{ideal}{}\left(x^{2}+y^{2}-1,\,x\,y-z^{2}\right)$
#
# o6 : <span><samp class="token class-name">Ideal</samp> of $R$</span>

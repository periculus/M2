# %% [markdown]
# # M2 Syntax Highlighting Test

# %%
-- This is a comment
-- Keywords: if, then, else, for, while
if true then print "hello" else print "world"

-- Types: Ring, Ideal, Matrix
R = QQ[x,y,z]  -- QQ should be highlighted as a type
I = ideal(x^2, y^2)  -- ideal should be a function

-- Functions: gb, res, decompose
gb I
res I
decompose I

-- Constants: true, false, null
x = true
y = false
z = null

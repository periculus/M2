# %% [markdown]
# # M2 Syntax Highlighting Test
#
# Open browser console to see debug messages from extension.

# %%
-- Test basic syntax elements
-- Keywords: if, then, else, do, for
-- Types: QQ, ZZ, RR, CC, Ring
-- Functions: ideal, gb, res, matrix

-- Numbers
x = 123
y = 3.14

-- Strings
s = "Hello World"

-- Comments should be gray
-* Block comment *-

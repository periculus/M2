# %%
-- Test M2 syntax highlighting
R = QQ[x,y,z]
I = ideal(x^2, y^2, z^2)
G = gb I
betti res I

# %%
-- Test keywords and control flow
if dim I == 0 then (
    print "Zero dimensional"
) else (
    print "Positive dimension"
)

# %%
-- Test function definition
f = x -> x^2 + 1
g = method()
g(ZZ) := n -> n^3

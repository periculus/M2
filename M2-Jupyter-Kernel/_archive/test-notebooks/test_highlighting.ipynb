# %%
-- Keywords test
if true then print "hello"
for i from 1 to 5 do print i

# %%
-- Types test
R = QQ[x,y,z]
S = ZZ/101
T = Ring

# %%
-- Functions test
I = ideal(x^2, y^2)
G = gb I
M = matrix {{1,2},{3,4}}

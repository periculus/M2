# %% [markdown]
# # M2 Syntax Highlighting Manual Test
#
# **IMPORTANT**: Make sure the kernel shows "Macaulay2" in the top right corner of the notebook!
#
# If it shows "No Kernel", click on it and select Macaulay2 from the list.
#
# ## Test Instructions
#
# 1. Open this notebook in JupyterLab
# 2. Ensure the Macaulay2 kernel is selected (check top right)
# 3. Look at the code cells below
# 4. Verify that:
#    - Keywords (if, then, else, return) are blue and bold
#    - Types (QQ, Ring, Matrix) are teal/cyan
#    - Functions (ideal, gb, matrix) are purple
#    - Numbers are orange
#    - Strings are green
#    - Comments are gray and italic

# %%
-- Test 1: Keywords (should be blue and bold)
if true then
    print "Keywords working!"
else
    return null
# Out:
# Error: stdio:7:0:(3): error: syntax error at 'else'\n
# stdio:7:0:(3): error: syntax error at 'else'

# %%
-- Test 2: Types (should be teal/cyan)
R = QQ[x,y,z]
S = ZZ/101
T = Ring
M = Matrix
# Out:
# Error: stdio:11:12:(3): error: syntax error at ']'\n
# stdio:11:12:(3): error: syntax error at ']'

# %%
-- Test 3: Functions (should be purple)
I = ideal(x^2, y^2, z^2)
G = gb I
M = matrix {{1,2,3},{4,5,6}}
res(I, LengthLimit => 5)

# %%
-- Test 4: Mixed example with all token types
-- Comments should be gray and italic
if QQ then                    -- Keyword (blue) and Type (teal)
    I = ideal(x^2 + 1)        -- Function (purple) and Number (orange)
    print "Success!"          -- Function (purple) and String (green)
else
    matrix {{0}}              -- Function (purple) and Number (orange)

# %%
-- Test 5: All keywords
if then else when while for do
break continue return try catch finally
new class method function symbol
protect export threadVariable global local
and or not xor
true false null

# %%
-- Test 6: All types
ZZ QQ RR CC
Ring Ideal Matrix Module
List Array String

# %%
-- Test 7: Common functions
print ideal gb matrix res
decompose primaryDecomposition
dim degree hilbertSeries

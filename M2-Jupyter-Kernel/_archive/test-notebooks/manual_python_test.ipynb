# %%
# Test Python syntax highlighting on M2 kernel
# These Python keywords should be highlighted:
if True:
    print("Hello")
else:
    pass

def my_function():
    return None

for i in range(10):
    continue

while False:
    break

class MyClass:
    pass

# %%
-- Also test M2 code
R = QQ[x,y,z]
I = ideal(x^2, y^2, z^2)
gb I

# %% [markdown]
# # Test: Multiple %def Commands
#
# This notebook tests that multiple `%def` commands work correctly in a single cell.

# %%
-- Define some symbols
S = QQ[a,b,c,d]
I = ideal(a^2, b^2, c^2)
f = x -> x^2 + x + 1
g = method()
g(ZZ) := n -> n * (n+1) / 2

# %%
-- Test multiple %def commands in one cell
%def S
%def I
%def f
%def g

# %%
-- Test %where magic too
%where ideal
%where gb
%where S

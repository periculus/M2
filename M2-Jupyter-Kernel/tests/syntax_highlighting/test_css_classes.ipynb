# %% [markdown]
# # M2 Syntax Highlighting Test
#
# This notebook tests M2 syntax highlighting.

# %%
-- Keywords test
if true then print "hello" else return null

# %%
-- Types test
R = QQ[x,y,z]; T = Ring; M = Matrix

# %%
-- Functions test
I = ideal(x^2); G = gb I; res(I, LengthLimit => 5)

# %%
-- Mixed test
if QQ then gb ideal(x) else matrix {{1,2},{3,4}}
